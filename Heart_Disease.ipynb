# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('CSV_files/heart_disease.csv')
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
print(data.shape)
# Out:
# (1025, 14)

# %%
print(data['target'].value_counts())
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.value_counts('thal')
# Out:
# thal
# 2    544
# 3    410
# 1     64
# 0      7
# Name: count, dtype: int64

# %%
sns.histplot(data['thalach'])
plt.title("Maximum Heart Rate Achieved")
plt.savefig('Maximum Heart Rate Achieved Distribution.png', dpi=300)
plt.show()

# %%
# Set the style and color palette for seaborn
sns.set(style="whitegrid")
sns.set_palette("Set2")  # Change the color palette for better aesthetics

# Plot histograms for continuous features with customizations
plt.figure(figsize=(15, 10))
data.hist(bins=20, color='skyblue', edgecolor='black', figsize=(15, 10))
plt.suptitle('Distribution of Continuous Features', fontsize=16)
plt.tight_layout()  # Adjust layout to prevent overlapping
# plt.savefig('Overiew of all columns.png', dpi=300)
plt.show()

# %%
data.duplicated().sum()
#We ignore the duplicates because they are intentional and most of the data can be similar to many patients
# Out:
# 723

# %%
sns.boxplot(x=data['age'])
# Out:
# <Axes: xlabel='age'>

# %%
# Example of label encoding for binary variables
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['sex'] = le.fit_transform(data['sex'])

# %%
data = pd.get_dummies(data, columns=['cp', 'thal'], drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data[['age', 'chol', 'thalach']] = scaler.fit_transform(data[['age', 'chol', 'thalach']])

# %%
data['age_group'] = pd.cut(data['age'], bins=[29, 39, 49, 59, 69, 79], labels=['30-39', '40-49', '50-59', '60-69', '70-79'])
# Out:
#            age  sex  trestbps      chol  fbs  restecg   thalach  exang  \
# 0    -0.268437    1       125 -0.659332    0        1  0.821321      0
# 1    -0.158157    1       140 -0.833861    1        0  0.255968      1
# 2     1.716595    1       145 -1.396233    0        1 -1.048692      1
# 3     0.724079    1       148 -0.833861    0        1  0.516900      0
# 4     0.834359    0       138  0.930822    1        1 -1.874977      0
# 5     0.393241    0       100  0.038784    0        0 -1.179158      0
# 6     0.393241    1       114  1.396233    0        2 -0.396362      0
# 7     0.062402    1       160  0.833861    0        0 -0.178919      1
# 8    -0.930114    1       120  0.058176    0        0 -0.222407      0
# 9    -0.047877    1       122  0.775685    0        0 -1.440090      1
# 10    1.826875    0       112 -1.881036    0        1 -1.048692      0
# 11   -1.260953    0       132  1.842251    1        0 -0.570317      1
# ...
